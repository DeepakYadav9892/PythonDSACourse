# %% [markdown]
# <span style="color:purple">
# <h2>why dsa required?? </h2></span>
# <span style="color:orange">
# Data Structures and Algorithms (DSA) are required because they teach you to solve problems efficiently, write optimized code, and build scalable software, forming the fundamental backbone of computer science essential for strong technical skills, better decision-making,
#
# 1)Array,2)Linked list,3)Stack ,4)Queue ,5)Tree , 6)Graph </span>

# %% [markdown]
# span style="color:purple">
# <h2>Algorithms </h2></span>
#
# <span style="color:orange">
# It is a combination of sequence of finite steps to solve any perticular problem.
# 1)Multiply two numbers
# step 1) Take two number a and b .
# step 2) Take c=a*b
# step 3) return c
#
#  </span>
#
#
#  <span style="color:green>
# Properties of algorithms :
# For an algorithm to be useful, it must satisfy five properties:
#     The inputs must be specified.
#     The outputs must be specified.
#     Definiteness.
#     Effectiveness.
#     Finiteness.
#
#  </span>

# %% [markdown]
# ##
