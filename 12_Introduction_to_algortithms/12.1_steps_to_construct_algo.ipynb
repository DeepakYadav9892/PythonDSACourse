# %% [markdown]
# <span style="color:orange">
# 1. Understand the Problem
# 2. Identify Inputs and Outputs
# 3. Design the Logic / Steps
# 4. Write the Algorithm (Step-by-Step) </span>

# %% [markdown]
# steps to construct algorithms
# while    --------> Loop ,while , for , do while
#
# while(True):
# print("Deepak Yadav")

# %% [markdown]
# <span style="color:orange">
# 1.Problem defination ---> constraints ,Parameter, test cases(end-to-end )
# 2)Design algorithms a)Devide and conquer
# b)Dynamic programming c) Greedy approach and manny more
# 3.Draw flow chart
# 4) Testing
# 5)Implementation(Python/c/c++/javascript)
# 6)Analysis
#
#  </span>
