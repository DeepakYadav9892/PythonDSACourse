# %% [markdown]
# """
# Soritn algorithms
# Bubble sort algorithms
#
# you are going to create bubble around two elements.
#
# Bubble Sort is one of the simplest sorting algorithms. It repeatedly compares adjacent elements in the list and swaps them if they are in the wrong order.
#
#
# How Bubble Sort Works
#
#     Compare each pair of adjacent elements.
#
#     If the first element is greater than the second, swap them.
#
#
#     After each full pass, the largest unsorted element "bubbles
#     up" to its correct position at the end.
#
#
#     Repeat this process for the remaining unsorted portion of the list.
#
#
#     The algorithm stops early if no swaps occur in a pass, meaning the array is already sorted.
#
#  """

# %%
def bubbleSort(arr):
    n = len(arr)
    for i in range(n):
        swapped = False
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        if not swapped:
            break  

arr = [64, 34, 25, 12, 22, 11, 90]
bubbleSort(arr)
print(arr)

# %% [markdown]
# Explanation:
#
#     for i in range(n):
#     wapped=false
#     for j in range(0,n-i-1):Iterates thorough unsorted elements; range shrinks as the end becomes sorted
#
#     if arr[j]>arr[j+1]: checks for inversion between adjancent Elements .
#
#     arr[j],arr[j+1]=arr[j+1],arr[j]: Swaps elements in place using tuple unpacking .
#
#     if not swapped:break , stops early if no swaps occur , indicating the array is already sorted.
