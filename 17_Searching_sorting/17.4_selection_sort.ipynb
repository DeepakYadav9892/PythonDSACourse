# %% [markdown]
# #Selection Sort:
#
#
# Selection sort is one of the simplest comparision based sorting algorithms.It sorts an array by repeatdly finding the smallest (or largest) element from the unsorted portion and placing it in its correct position.
#
#
# Working of selection sort algo :
#
#
#
# Working of Selection Sort
#
#     Start from the first element and find the smallest element in the entire array by iterating over it.
#
#
#     Swap this smallest element with the first element.
#
#
#     Now, move to the second element find the next smallest in the remaining unsorted portion and swap it with the second position.
#
#
#     Repeat this process until the entire array becomes sorted.

# %%
def selectionSort(array, size):
    for ind in range(size):
        min_index = ind

        for j in range(ind + 1, size):
            if array[j] < array[min_index]:
                min_index = j

        array[ind], array[min_index] = array[min_index], array[ind]

arr = [-2, 45, 0, 11, -9, 88, -97, -202, 747]
size = len(arr)
selectionSort(arr, size)

print(arr)
# Out:
# [-202, -97, -9, -2, 0, 11, 45, 88, 747]

# %% [markdown]
# Explanation:
#
# for ind in range(size):
#
# min_index=ind
#
# for j in range (ind+1,size)
#
#
# if array[j]< array[min_index ]>

# %%
#same program using list 
def selection_sort(lst):
    n = len(lst)

    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if lst[j] < lst[min_index]:
                min_index = j
        lst[i], lst[min_index] = lst[min_index], lst[i]

    return lst

data = [64, 25, 12, 22, 11]
print(selection_sort(data))
