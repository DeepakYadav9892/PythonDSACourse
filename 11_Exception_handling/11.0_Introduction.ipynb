# %% [markdown]
# <span style="color:Orange">Exception Handling
# Python's exception handling uses
# try, except, else, and finally blocks to manage runtime errors and prevent program crashes. This mechanism allows you to separate error-handling code from the main business logic, making programs more robust and readable.
# try, except , else , finally key words used, different components
# core components: Try : A block of code containing statements that might reaise an exceptionn.
#
# except: Catches and handles an exception if one occurs within the preceding try block . You can specify the exact exception type of handle, or multiple types of tuple .
# else: the code within this block is executed only if no exception was raised in the try block .
# finally: The code within this block is always executed , regardless of whhethre an exceptionn occcurred or not. It is primarily se
# </span>

# %% [markdown]
# Exception handling
# A milk spil , missing ingredient , brew step .
# orders=["masala","ginger]
# print(orders[2])

# %%
orders=["masala","ginger"]
print(orders[1])
# Out:
# ginger
